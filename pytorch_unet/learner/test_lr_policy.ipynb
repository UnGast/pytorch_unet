# %%
# %load_ext autoreload
from pathlib import Path
import matplotlib.pyplot as plt
import sys
sys.path.append(str(Path('../../').resolve()))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Test OneCycleLRPolicy

# %%
from lr_policy import OneCycleLRPolicy
policy = OneCycleLRPolicy(max_lr=3e-3, step_count=100)
data = [policy.get_lr_for(epoch=i, batch=0) for i in range(0, 300)]
plt.plot(data)
