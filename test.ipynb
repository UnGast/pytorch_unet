# %%
# %load_ext autoreload

# %%
# %matplotlib inline
from pathlib import Path
import matplotlib.pyplot as plt
import torch
import time

# %%
#fig, axes = plt.subplots(1, 3)
#im = axes[0].imshow(torch.randn(400, 400))
im = plt.imshow(torch.randn(500, 600))

for i in range(0, 10):
    im.set_data(torch.randn(500, 600))
    #axes[0].imshow(torch.randn(500, 500))
    #fig.canvas.draw()
    #fig.show()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5a3daf49e67c> in <module>
#       8     #fig.canvas.draw()
#       9     #fig.show()
# ---> 10     time.sleep(1)
#
# KeyboardInterrupt:

# %%
im.set_data(torch.randn(500, 500))
fig.canvas.draw()
fig.show()

# %%
import pandas as pd

# %%
data = [[1, 2], [3, 4]]
pd.DataFrame(data, columns=["Foo", "Bar"])
# Out:
#    Foo  Bar
# 0    1    2
# 1    3    4

# %%
import sys
sys.path.append(str(Path('../../').resolve()))

# %%
# %autoreload
from v4.pytorch_unet.learner_checkpoint_analyzer import LearnerCheckpointAnalyzer

analyzer = LearnerCheckpointAnalyzer()
analyzer.add_all_checkpoints_in_directory(Path('test_checkpoints'))
overview = analyzer.make_overview()
overview
# Out:
# model: test_unet_3
#    epoch  train_loss  valid_loss  train_accuracy  valid_accuracy
# 0      0    0.321526    0.322246        0.373969        0.370706
# 1      1    0.320219    0.319833        0.373969        0.370706
# 2      2    0.317851    0.317446        0.373969        0.370706
# 3      3    0.315590    0.315500        0.373969        0.370706
# 4      4    0.313603    0.313560        0.373969        0.370706
# 5      5    0.311900    0.312129        0.373969        0.370706
# 6      6    0.310550    0.311160        0.373969        0.370706
# 7      7    0.309663    0.310382        0.373969        0.370706
# 8      8    0.309174    0.310138        0.373969        0.370706
# 9      9    0.309081    0.310138        0.373969        0.370706

# %%
testarr = [3, 1, 10, 2]
testarr.sort()

# %%
testarr
# Out:
# [1, 2, 3, 10]

# %%
testarr[1:3]
# Out:
# [2, 3]
