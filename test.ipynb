# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import torch
import time

# %%
#fig, axes = plt.subplots(1, 3)
#im = axes[0].imshow(torch.randn(400, 400))
im = plt.imshow(torch.randn(500, 600))

for i in range(0, 10):
    im.set_data(torch.randn(500, 600))
    #axes[0].imshow(torch.randn(500, 500))
    #fig.canvas.draw()
    #fig.show()
    time.sleep(1)

# %%
im.set_data(torch.randn(500, 500))
fig.canvas.draw()
fig.show()
